# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_Competitive_DS/blob/week_5/CompetitiveDS_5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #5.2.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5.2.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5.2.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5.2.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Чем лучше параметры, туда больше и докидываются проходов.
