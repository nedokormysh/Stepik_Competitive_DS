# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_Competitive_DS/blob/week_6/CompetitiveDS_6_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6.1.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6.1.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6.1.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = '3'
s = '0.3 0.5 0.4'

# %%
n = int(input())
s = input().split()
# Out:
# 3
# 0.3 0.5 0.4

# %%
scores = []
for i in range(n):
    scores.append(float(s[i]))

# %%
import numpy as np

# %%
s = np.sum(scores)

# %%
weights = []

# %%
weights = scores / s

# %%
[round(i, 7) for i in weights]
# Out:
# [0.25, 0.4166667, 0.3333333]

# %%
import numpy as np
n = int(input())
s = input().split()
scores = []
for i in range(n):
    scores.append(float(s[i]))

s = np.sum(scores)
weights = scores / s
[round(i, 7) for i in weights]

# %%
sum(scores)
# Out:
# 1.2000000000000002

# %%
weights = [score/sum(scores) for score in scores]

# %% [markdown]
# # 6.1.7

# %% [markdown]
# Задание: Cделай голосование этих моделей. Результат запишите в столбец target_class. Финальный файл с решением должен включать в себя только два столбца: car_id и target_class. Вот пример, который должен выглядеть как-то так:

# %%
import pandas as pd

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/make_soft_blend.csv')
df.head()
# Out:
#   car_id  target_class          model_1          model_2          model_3  \
# 0  car_0           NaN      electro_bug       gear_stick      electro_bug
# 1  car_1           NaN     engine_check  engine_overheat      electro_bug
# 2  car_2           NaN      another_bug      electro_bug  engine_overheat
# 3  car_3           NaN      electro_bug      electro_bug      electro_bug
# 4  car_4           NaN  engine_ignition      another_bug     engine_check
#
#            model_4          model_5
# 0      electro_bug  engine_ignition
# 1  engine_overheat  engine_overheat
# 2  engine_overheat       gear_stick
# 3      wheel_shake      electro_bug
# 4     engine_check     engine_check

# %%
from collections import Counter

# %%
words_to_count = ['electro_bug',	'gear_stick',	'electro_bug',	'electro_bug',	'engine_ignition']

c = Counter(words_to_count)
print(c.most_common()[0][0])
# Out:
# electro_bug

# %%
df.iloc[0].value_counts().index[0]
# .value_counts().index.tolist()
# Out:
# 'electro_bug'

# %%
def hard_voting(row):
  # print(row.value_counts().index[0])
  return row.value_counts().index[0]

# %%
df['target_class'] = df.apply(hard_voting, axis=1)

# %%
df.head()
# Out:
#   car_id     target_class          model_1          model_2          model_3  \
# 0  car_0      electro_bug      electro_bug       gear_stick      electro_bug
# 1  car_1  engine_overheat     engine_check  engine_overheat      electro_bug
# 2  car_2  engine_overheat      another_bug      electro_bug  engine_overheat
# 3  car_3      electro_bug      electro_bug      electro_bug      electro_bug
# 4  car_4     engine_check  engine_ignition      another_bug     engine_check
#
#            model_4          model_5
# 0      electro_bug  engine_ignition
# 1  engine_overheat  engine_overheat
# 2  engine_overheat       gear_stick
# 3      wheel_shake      electro_bug
# 4     engine_check     engine_check

# %%
df = df[['car_id', 'target_class']]
df
# Out:
#         car_id     target_class
# 0        car_0      electro_bug
# 1        car_1  engine_overheat
# 2        car_2  engine_overheat
# 3        car_3      electro_bug
# 4        car_4     engine_check
# ...        ...              ...
# 1908  car_1908        break_bug
# 1909  car_1909        break_bug
# 1910  car_1910  engine_overheat
# 1911  car_1911     engine_check
# 1912  car_1912     engine_check
#
# [1913 rows x 2 columns]

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/make_soft_blend.csv')
df['target_class'] = df.apply(lambda row: row.value_counts().index[0], axis=1)
df = df[['car_id', 'target_class']]
df.head()
# Out:
#   car_id     target_class
# 0  car_0      electro_bug
# 1  car_1  engine_overheat
# 2  car_2  engine_overheat
# 3  car_3      electro_bug
# 4  car_4     engine_check

# %%
df.to_csv('try_0.csv', index=False)

# %% [markdown]
# # 6.1.8

# %%
df_catboost_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/catboost_preds.csv')
df_catboost_preds.head()
# Out:
#    another_bug_proba  break_bug_proba  electro_bug_proba  engine_check_proba  \
# 0           0.112482         0.117905           0.102009            0.115111
# 1           0.131855         0.114520           0.111594            0.113760
# 2           0.112382         0.117429           0.104545            0.106867
# 3           0.117932         0.117098           0.102200            0.119365
# 4           0.109022         0.117847           0.103836            0.117278
#
#    engine_fuel_proba  engine_ignition_proba  engine_overheat_proba  \
# 0           0.105105               0.111646               0.108378
# 1           0.099113               0.108545               0.105714
# 2           0.105233               0.112577               0.112477
# 3           0.101529               0.106561               0.110749
# 4           0.103819               0.109251               0.115560
#
#    gear_stick_proba  wheel_shake_proba
# 0          0.128776           0.098588
# ...

# %%
df_lgbm_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/lgbm_preds.csv')
df_lgbm_preds.head()
# Out:
#    another_bug_proba  break_bug_proba  electro_bug_proba  engine_check_proba  \
# 0           0.120016         0.113801           0.114904            0.108070
# 1           0.159507         0.211517           0.084138            0.099253
# 2           0.120716         0.111604           0.107702            0.111085
# 3           0.111751         0.117286           0.105884            0.118102
# 4           0.129088         0.143763           0.101267            0.098094
#
#    engine_fuel_proba  engine_ignition_proba  engine_overheat_proba  \
# 0           0.118519               0.105637               0.121196
# 1           0.082684               0.087642               0.113180
# 2           0.104361               0.126828               0.121338
# 3           0.108398               0.114491               0.109710
# 4           0.095252               0.125343               0.117536
#
#    gear_stick_proba  wheel_shake_proba
# 0          0.113500           0.084358
# ...

# %%
df_xgb_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/xgb_preds.csv')
df_xgb_preds.head()
# Out:
#    another_bug_proba  break_bug_proba  electro_bug_proba  engine_check_proba  \
# 0           0.104721         0.112521           0.137060            0.090919
# 1           0.188389         0.116850           0.096975            0.120398
# 2           0.115143         0.113272           0.105387            0.111472
# 3           0.109527         0.112851           0.109656            0.136960
# 4           0.121198         0.110750           0.130662            0.098771
#
#    engine_fuel_proba  engine_ignition_proba  engine_overheat_proba  \
# 0           0.122933               0.105311               0.106699
# 1           0.098549               0.088542               0.109467
# 2           0.097676               0.122911               0.114653
# 3           0.091574               0.120251               0.090839
# 4           0.132158               0.112390               0.102490
#
#    gear_stick_proba  wheel_shake_proba
# 0          0.110659           0.109176
# ...

# %%
res = df_catboost_preds + df_lgbm_preds + df_xgb_preds
res.head()
# Out:
#    another_bug_proba  break_bug_proba  electro_bug_proba  engine_check_proba  \
# 0           0.337219         0.344227           0.353973            0.314100
# 1           0.479751         0.442886           0.292707            0.333411
# 2           0.348240         0.342305           0.317633            0.329424
# 3           0.339210         0.347235           0.317740            0.374427
# 4           0.359307         0.372359           0.335765            0.314143
#
#    engine_fuel_proba  engine_ignition_proba  engine_overheat_proba  \
# 0           0.346557               0.322595               0.336272
# 1           0.280346               0.284728               0.328361
# 2           0.307271               0.362316               0.348468
# 3           0.301501               0.341304               0.311298
# 4           0.331229               0.346983               0.335586
#
#    gear_stick_proba  wheel_shake_proba
# 0          0.352935           0.292123
# ...

# %%
res.iloc[0]
# Out:
# another_bug_proba        0.337219
# break_bug_proba          0.344227
# electro_bug_proba        0.353973
# engine_check_proba       0.314100
# engine_fuel_proba        0.346557
# engine_ignition_proba    0.322595
# engine_overheat_proba    0.336272
# gear_stick_proba         0.352935
# wheel_shake_proba        0.292123
# Name: 0, dtype: float64

# %%
res.idxmax(axis=1).map(lambda x: x.lstrip('_proba'))
# Out:
# 0          electro_bug_proba
# 1           nother_bug_proba
# 2      engine_ignition_proba
# 3           gear_stick_proba
# 4              eak_bug_proba
#                ...
# 580         nother_bug_proba
# 581         gear_stick_proba
# 582            eak_bug_proba
# 583         gear_stick_proba
# 584         gear_stick_proba
# Length: 585, dtype: object

# %%
df_catboost_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/catboost_preds.csv')
df_lgbm_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/lgbm_preds.csv')
df_xgb_preds = pd.read_csv('https://stepik.org/media/attachments/lesson/825510/xgb_preds.csv')

res = df_catboost_preds + df_lgbm_preds + df_xgb_preds
res['soft_preds'] = res.idxmax(axis=1)
res = res[['soft_preds']].applymap(lambda x: x.rstrip('_proba'))
# res = res[['soft_preds']]
res
# Out:
#           soft_preds
# 0        electro_bug
# 1        another_bug
# 2    engine_ignition
# 3         gear_stick
# 4          break_bug
# ..               ...
# 580      another_bug
# 581       gear_stick
# 582        break_bug
# 583       gear_stick
# 584       gear_stick
#
# [585 rows x 1 columns]

# %%
res.to_csv('try_2.csv')

# %%
'electro_bug_proba'.rstrip('_proba')
# Out:
# 'electro_bug'

# %% [markdown]
# # 6.1.10

# %% [markdown]
# Реализуйте процедуру нормализации вероятностей, как описывалось в предыдущем шаге. На вход вам дается датасет с предсказаниями для одной модели.

# %%
id = [0, 1, 2, 3, 4]
proba = [0.374540, 0.950714, 0.731994, 0.598658, 0.156019]

# %%
df = pd.DataFrame(id, columns=['id'])
df
# Out:
#    id
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4

# %%
df['proba']=proba

# %%
df
# Out:
#    id     proba
# 0   0  0.374540
# 1   1  0.950714
# 2   2  0.731994
# 3   3  0.598658
# 4   4  0.156019

# %%
df['proba'].rank()
# Out:
# 0    2.0
# 1    5.0
# 2    4.0
# 3    3.0
# 4    1.0
# Name: proba, dtype: float64

# %%
len(df)
# Out:
# 5

# %%
df['normalized_proba'] = df['proba'].rank()/len(df)
df
# Out:
#    id     proba  normalized_proba
# 0   0  0.374540               0.4
# 1   1  0.950714               1.0
# 2   2  0.731994               0.8
# 3   3  0.598658               0.6
# 4   4  0.156019               0.2

# %% [markdown]
# # 6.1.12

# %% [markdown]
# Заполните пропуски
# Напишите названия .py файлов, которые нужно использовать из библиотеки Kaggle-Ensemble-Guide, чтобы сблендить тем или иным способом.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6.1.13

# %% [markdown]
# Задача: отметь основные принципы блендинга.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
